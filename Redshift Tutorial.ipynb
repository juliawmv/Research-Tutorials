# %%
# makes flat cosmology from a cosmology object

from astropy.cosmology import FlatLambdaCDM
import astropy.units as u

# In this case we just need to define the matter density 
# and hubble parameter at z=0.

# Note the default units for the hubble parameter H0 are km/s/Mpc. 
# We will pass in a `Quantity` object with the units specified. 

cosmo = FlatLambdaCDM(H0=70*u.km/u.s/u.Mpc, Om0=0.3)

# %%
# plots angular diameter distance versus redshift

import numpy as np
import scipy.special
import matplotlib.pyplot as plt
zvals = np.arange(0, 6, 0.1)
dist = cosmo.angular_diameter_distance(zvals)

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.plot(zvals, dist)

# %%
# check diameter distance units

dist.unit
# Out:
# Unit("Mpc")

# %%
# generates ages in Gyr for axis ticks

ages = np.array([13, 10, 8, 6, 5, 4, 3, 2, 1.5, 1.2, 1])*u.Gyr

# %%
# links redshift axis to age axis

from astropy.cosmology import z_at_value
ageticks = [z_at_value(cosmo.age, age) for age in ages]

# %%
# plots angular diameter distance versus redshift with axises

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.plot(zvals, dist)
ax2 = ax.twiny()
ax2.set_xticks(ageticks)
# Out:
# [<matplotlib.axis.XTick at 0x285526b0da0>,
#  <matplotlib.axis.XTick at 0x285527d3140>,
#  <matplotlib.axis.XTick at 0x28552797b30>,
#  <matplotlib.axis.XTick at 0x285527d2c60>,
#  <matplotlib.axis.XTick at 0x285528036e0>,
#  <matplotlib.axis.XTick at 0x28552778740>,
#  <matplotlib.axis.XTick at 0x28552803b90>,
#  <matplotlib.axis.XTick at 0x2855282c500>,
#  <matplotlib.axis.XTick at 0x2855282ce00>,
#  <matplotlib.axis.XTick at 0x2855282d6d0>,
#  <matplotlib.axis.XTick at 0x285527af0b0>]

# %%
# fixes redshift labels

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.plot(zvals, dist)
ax2 = ax.twiny()
ax2.set_xticks(ageticks)
ax2.set_xticklabels(['{:g}'.format(age) for age in ages.value])
# Out:
# [Text(0.03426542424730716, 1, '13'),
#  Text(0.30529969870539064, 1, '10'),
#  Text(0.5622761997285902, 1, '8'),
#  Text(0.9394313081990149, 1, '6'),
#  Text(1.2114538180402323, 1, '5'),
#  Text(1.586736130025453, 1, '4'),
#  Text(2.153211270001333, 1, '3'),
#  Text(3.1503817535239285, 1, '2'),
#  Text(4.035713900198318, 1, '1.5'),
#  Text(4.84767084618423, 1, '1.2'),
#  Text(5.606047443188418, 1, '1')]

# %%
# Gives both axes the same redshift limits

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.plot(zvals, dist)
ax2 = ax.twiny()
ax2.set_xticks(ageticks)
ax2.set_xticklabels(['{:g}'.format(age) for age in ages.value])
zmin, zmax = 0.0, 5.9
ax.set_xlim(zmin, zmax)
ax2.set_xlim(zmin, zmax)
# Out:
# (0.0, 5.9)

# %%
# adds labels to axes and adjusts tick marks

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.plot(zvals, dist)
ax2 = ax.twiny()
ax2.set_xticks(ageticks)
ax2.set_xticklabels(['{:g}'.format(age) for age in ages.value])
zmin, zmax = 0, 5.9
ax.set_xlim(zmin, zmax)
ax2.set_xlim(zmin, zmax)
ax2.set_xlabel('Time since Big Bang (Gyr)')
ax.set_xlabel('Redshift')
ax.set_ylabel('Angular diameter distance (Mpc)')
ax.set_ylim(0, 1890)
ax.minorticks_on()

# %%
# adds cosmology parameters from Planck 2013 and saves the figure to a png file

from astropy.cosmology import Planck13
dist2 = Planck13.angular_diameter_distance(zvals)

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.plot(zvals, dist2, label='Planck 2013')
ax.plot(zvals, dist, label=
        '$h=0.7,\ \Omega_M=0.3,\ \Omega_\Lambda=0.7$')
ax.legend(frameon=0, loc='lower right')
ax2 = ax.twiny()
ax2.set_xticks(ageticks)
ax2.set_xticklabels(['{:g}'.format(age) for age in ages.value])
zmin, zmax = 0.0, 5.9
ax.set_xlim(zmin, zmax)
ax2.set_xlim(zmin, zmax)
ax2.set_xlabel('Time since Big Bang (Gyr)')
ax.set_xlabel('Redshift')
ax.set_ylabel('Angular diameter distance (Mpc)')
ax.minorticks_on()
ax.set_ylim(0, 1890)
fig.savefig('ang_dist.png', dpi=200, bbox_inches='tight')
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\ '
# <>:10: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\julia\AppData\Local\Temp\ipykernel_18900\3085203441.py:10: SyntaxWarning: invalid escape sequence '\ '
#   '$h=0.7,\ \Omega_M=0.3,\ \Omega_\Lambda=0.7$')

# %%
# need to add 2nd upper axis for updated universe age

from astropy.cosmology import Planck13
dist2 = Planck13.angular_diameter_distance(zvals)
#ageticks2 = np.array([13.8, 10, 8, 6, 5, 4, 3, 2, 1.5, 1.2, 1])*u.Gyr

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.plot(zvals, dist2, label='Planck 2013')
ax.plot(zvals, dist, label=
        '$h=0.7,\ \Omega_M=0.3,\ \Omega_\Lambda=0.7$')
ax.legend(frameon=0, loc='lower right')
ax2 = ax.twiny()
ax2.set_xticks(ageticks)
ax2.set_xticklabels(['{:g}'.format(age) for age in ages.value])
zmin, zmax = 0.0, 5.9
ax.set_xlim(zmin, zmax)
ax2.set_xlim(zmin, zmax)
ax2.set_xlabel('Time since Big Bang (Gyr)')
ax.set_xlabel('Redshift')
ax.set_ylabel('Angular diameter distance (Mpc)')
ax.minorticks_on()
ax.set_ylim(0, 1890)
fig.savefig('ang_dist.png', dpi=200, bbox_inches='tight')

# Twin the -axis twice to make independent y-axes.
axes = [ax, ax.twinx(), ax.twinx()]

# Make some space on the right side for the extra y-axis.
fig.subplots_adjust(right=0.75)

# Move the last y-axis spine over to the right by 20% of the width of the axes
axes[-1].spines['right'].set_position(('axes', 1.2))

# To make the border of the right-most axis visible, we need to turn the frame
# on. This hides the other plots, however, so we need to turn its fill off.
axes[-1].set_frame_on(True)
axes[-1].patch.set_visible(False)

# And finally we get to plot things...
colors = ('Green', 'Red', 'Blue')
for ax, color in zip(axes, colors):
    data = np.random.random(1) * np.random.random(10)
    ax.plot(data, marker='o', linestyle='none', color=color)
    ax.set_ylabel('%s Thing' % color, color=color)
    ax.tick_params(axis='y', colors=color)
axes[0].set_xlabel('X-axis')

plt.show()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\ '
# <>:11: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\julia\AppData\Local\Temp\ipykernel_18900\2328486329.py:11: SyntaxWarning: invalid escape sequence '\ '
#   '$h=0.7,\ \Omega_M=0.3,\ \Omega_\Lambda=0.7$')
# C:\Users\julia\AppData\Local\Temp\ipykernel_18900\2328486329.py:11: SyntaxWarning: invalid escape sequence '\ '
#   '$h=0.7,\ \Omega_M=0.3,\ \Omega_\Lambda=0.7$')
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# Cell In[19], line 16
#      14 ax2.set_xticks(ageticks)
#      15 ax3 = ax.twiny()
# ---> 16 ax3.set_xticks(ageticks1)
#      17 ax2.set_xticklabels(['{:g}'.format(age) for age in ages.value])
#      18 ax3.set_xticklabels(['{:b}'.format(age) for age in ages.value])
#
# File ~\jupyter_playground\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~\jupyter_playground\Lib\site-packages\matplotlib\axis.py:2138, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2133     first_key = next(iter(kwargs))
#    2134     raise ValueError(
#    2135         f"Incorrect use of keyword argument {first_key!r}. Keyword arguments "
#    2136         "other than 'minor' modify the text labels and can only be used if "
#    2137         "'labels' are passed as well.")
# -> 2138 result = self._set_tick_locations(ticks, minor=minor)
#    2139 if labels is not None:
#    2140     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~\jupyter_playground\Lib\site-packages\matplotlib\axis.py:2082, in Axis._set_tick_locations(self, ticks, minor)
#    2079 if len(ticks):
#    2080     for axis in self._get_shared_axis():
#    2081         # set_view_interval maintains any preexisting inversion.
# -> 2082         axis.set_view_interval(min(ticks), max(ticks))
#    2083 self.axes.stale = True
#    2084 if minor:
#
# File ~\jupyter_playground\Lib\site-packages\matplotlib\axis.py:2276, in _make_getset_interval.<locals>.setter(self, vmin, vmax, ignore)
#    2274 oldmin, oldmax = getter(self)
#    2275 if oldmin < oldmax:
# -> 2276     setter(self, min(vmin, vmax, oldmin), max(vmin, vmax, oldmax),
#    2277            ignore=True)
#    2278 else:
#    2279     setter(self, max(vmin, vmax, oldmin), min(vmin, vmax, oldmax),
#    2280            ignore=True)
#
# File ~\jupyter_playground\Lib\site-packages\astropy\units\quantity.py:691, in Quantity.__array_ufunc__(self, function, method, *inputs, **kwargs)
#     689     return NotImplemented
#     690 else:
# --> 691     raise e
#
# File ~\jupyter_playground\Lib\site-packages\astropy\units\quantity.py:636, in Quantity.__array_ufunc__(self, function, method, *inputs, **kwargs)
#     631 # Determine required conversion functions -- to bring the unit of the
#     632 # input to that expected (e.g., radian for np.sin), or to get
#     633 # consistent units between two inputs (e.g., in np.add) --
#     634 # and the unit of the result (or tuple of units for nout > 1).
#     635 try:
# --> 636     converters, unit = converters_and_unit(function, method, *inputs)
#     638     out = kwargs.get("out", None)
#     639     # Avoid loop back by turning any Quantity output into array views.
#
# File ~\jupyter_playground\Lib\site-packages\astropy\units\quantity_helper\converters.py:199, in converters_and_unit(function, method, *args)
#     197             converters[i] = None
#     198         else:
# --> 199             raise UnitConversionError(
#     200                 f"Can only apply '{function.__name__}' function to "
#     201                 "dimensionless quantities when other argument is not "
#     202                 "a quantity (unless the latter is all zero/infinity/nan)."
#     203             )
#     204 except TypeError:
#     205     # _can_have_arbitrary_unit failed: arg could not be compared
#     206     # with zero or checked to be finite. Then, ufunc will fail too.
#     207     raise TypeError(
#     208         "Unsupported operand type(s) for ufunc {}: '{}'".format(
#     209             function.__name__,
#     210             ",".join([arg.__class__.__name__ for arg in args]),
#     211         )
#     212     )
#
# UnitConversionError: Can only apply 'less' function to dimensionless quantities when other argument is not a quantity (unless the latter is all zero/infinity/nan).
